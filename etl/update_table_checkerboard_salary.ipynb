# %%
import pandas as pd
import pymssql
from clickhouse_driver import Client
from sqlalchemy import create_engine
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
def execute_clickhouse(query="select 'Test' as Test",
                       database='dns_retail',
                       external_tables=None,
                       **kwargs) -> pd.DataFrame:
    """
    Функция для выполнения запросов к Clickhouse

    **Аргументы:**

    - `query: str` - запрос
    - `database: str` - база данных (по-умолчанию `'dns_log'`)
    - `external_tables: pandas.DataFrame` - датафрэйм из которого бдует генерироваться внешняя таблица

    **Возвращает:**
    >    `pandas.DataFrame` с результатом запроса
    """
    client = Client(
        host='',
        port='',
        database=database,
        user='',
        password=''
    )
    
    if external_tables:
        pass
        #external_tables = [df_to_table(table[0], table[1]) for table in external_tables]

    rv = client.execute(query, external_tables=external_tables, with_column_types=True)
    df = pd.DataFrame(rv[0])
    df.columns = [i[0] for i in rv[1]]
    return df

def execute_pg_hr(query):
    """Функция обращения к хранилищу mart_hr DNS на чтение
    Параметры:
    query - строка, SQL запрос
    Возвращает - pandas DataFrame с содержанием результата выполнения запроса, названия столбцов из запроса"""

    host = ''
    schema = ''
    login = ''
    password = ''

    conection_url = f'postgresql+psycopg2://{login}:{password}@{host}/{schema}'

    engine = create_engine(conection_url)
    df = pd.read_sql(query, engine)
    engine.dispose()
    return df

def get_postgres_connection_string(connection_id) -> str:
    """
    Возвращает строку подключения к postgres для указанного подключения
    :return:
    """
    class connection:
        login = ''
        password = ''
        host = ''
        port = ''
        schema = ''

    return f'postgresql+psycopg2://{connection.login}:{connection.password}@{connection.host}:{connection.port}/{connection.schema}'

def execute_onec(query):
    """Функция обращения к Хранилищу DNS на чтение
    Параметры:
    query - строка, SQL запрос
    Возвращает - pandas DataFrame с содержанием результата выполнения запроса, названия столбцов из запроса"""
    ADuser = 'O'
    ADpassword = ''
    # ADuser = Config.ONEC_LOGIN
    # ADpassword = Config.ONEC_PASSWORD
    conn = pymssql.connect(server='', user=ADuser, password=ADpassword, database='')
    df = pd.read_sql(query, conn)
    
    return df

# %%
def GetPosLvlSalary():
    query = f"""                                                                                                                                                                               
	WITH first_query AS
	(
	SELECT  
	--		reg_table.Должность AS Должность
			dwh.[Справочник.ШтатноеРасписание].Наименование AS Должность
			,reg_table.Уровень AS Уровень
			,dwh.[Справочник.Города].Наименование AS Город
			,reg_table.Значение AS Зарплата
			, MAX(convert(date, Период)) OVER (PARTITION BY Должность, Уровень, Город) AS max_period
			,convert(date, reg_table.Период) as Период 
	FROM dwh.[РегистрСведений.УровеньЗаработнойПлаты] AS reg_table
	JOIN dwh.[Справочник.Города] ON reg_table.Город = dwh.[Справочник.Города].Ссылка 
	JOIN dwh.[Справочник.ШтатноеРасписание] ON reg_table.Должность  =  dwh.[Справочник.ШтатноеРасписание].Ссылка  
	)

	SELECT Город, Должность, Уровень, Зарплата, Период, CONVERT(DATE, GETDATE()) AS ДатаОбновления
	FROM  first_query
	WHERE Период = max_period
		AND Должность != '2.03. Фед.развитие сайта'
		AND Должность not like '%(на аутсорсе)%' 
	ORDER BY Зарплата """
    df = execute_onec(query)
    return df

# %%
def getActualStaff():
    query = f"""
  select
      as2."ДатаОбновления" 
    , as2."Должность"
    , as2."УровеньОплаты"
    , as2."ТекущийФилиал"
    ,count(*) as КоличествоСотрудников
  from actual_staff as2
  where as2."Должность" not like '%%(на аутсорсе)%%'
  group by as2."Должность", as2."РасчетнаяЗарплата", as2."УровеньОплаты", as2."ТекущийФилиал", as2."ДатаОбновления" 
  order by as2."Должность", as2."ТекущийФилиал", as2."УровеньОплаты" """
    df = execute_pg_hr(query)
    return df

# %%
def getBranchCity():
	query = f"""
	select 
	  bh.BranchCode 
	, bh.BranchName as "Филиал"
	, replace(bh.CityName, 'РКЦ ', '') as "Город"
from dns_retail.BranchHier bh 
	"""
	df = execute_clickhouse(query)
	return df

# %%
df_PosLvlSalary = GetPosLvlSalary()
df_PosLvlSalary
# Out:
#                  Город                Должность  Уровень  Зарплата  \
# 0           Всеволожск  Управляющий СЦ В-класса      1.0       0.0
# 1         Великие Луки  Управляющий СЦ В-класса      1.0       0.0
# 2              Гатчина  Управляющий СЦ В-класса      1.0       0.0
# 3              Колпино  Управляющий СЦ В-класса      1.0       0.0
# 4            Кингисепп  Управляющий СЦ В-класса      1.0       0.0
# ...                ...                      ...      ...       ...
# 63677  Санкт-Петербург       Директор дивизиона      3.0  300000.0
# 63678          Воронеж       Директор дивизиона      3.0  300000.0
# 63679      Владивосток                 Директор      3.0  300000.0
# 63680      Владивосток     Федеральный директор      3.0  300000.0
# 63681  Санкт-Петербург     Федеральный директор      3.0  300000.0
#
#            Период ДатаОбновления
# 0      2020-06-01     2022-07-08
# 1      2020-06-01     2022-07-08
# 2      2020-06-01     2022-07-08
# 3      2020-06-01     2022-07-08
# 4      2020-06-01     2022-07-08
# ...           ...            ...
# 63677  2021-12-01     2022-07-08
# 63678  2021-12-01     2022-07-08
# 63679  2021-12-01     2022-07-08
# 63680  2021-12-01     2022-07-08
# 63681  2021-12-01     2022-07-08
#
# [63682 rows x 6 columns]

# %%
df_actual_staff = getActualStaff()
df_actual_staff
# Out:
#                ДатаОбновления                 Должность  УровеньОплаты  \
# 0     2022-07-08 14:36:46.910  Администратор киностудии            2.0
# 1     2022-07-08 14:36:46.910       Администратор офиса            2.0
# 2     2022-07-08 14:36:46.910       Администратор офиса            3.0
# 3     2022-07-08 14:36:46.910       Администратор офиса            1.0
# 4     2022-07-08 14:36:46.910       Администратор офиса            2.0
# ...                       ...                       ...            ...
# 18517 2022-07-08 14:36:46.910                     Юрист            3.0
# 18518 2022-07-08 14:36:46.910                     Юрист            1.0
# 18519 2022-07-08 14:36:46.910                     Юрист            2.0
# 18520 2022-07-08 14:36:46.910                     Юрист            3.0
# 18521 2022-07-08 14:36:46.910      Юрист службы сервиса            2.0
#
#        ТекущийФилиал  КоличествоСотрудников
# 0             2421.0                      1
# 1              284.0                      1
# 2              292.0                      1
# 3              897.0                      1
# 4              897.0                      1
# ...              ...                    ...
# 18517         5822.0                      1
# 18518         5823.0                      2
# 18519         5823.0                      1
# 18520         5823.0                      1
# 18521         6155.0                      3
#
# [18522 rows x 5 columns]

# %%
df_branch_city = getBranchCity()
df_branch_city
# Out:
#       BranchCode                                 Филиал        Город
# 0         4652.0              Волоколамск ТЦ Кооператор  Волоколамск
# 1         1520.0  Северск на Коммунистическом (ЗАКРЫТО)      Северск
# 2         1907.0              Самара ТЦ Юг ТП (ЗАКРЫТО)       Самара
# 3         6103.0         IT-группа 1С "Учет и Рибейты"   Владивосток
# 4         2570.0             Тольятти ТЦ Вега (ЗАКРЫТО)     Тольятти
# ...          ...                                    ...          ...
# 6164        25.0    Хаб Склад (ЗАКРЫТ, НЕ ИСПОЛЬЗОВАТЬ)    Хабаровск
# 6165      4093.0                 Хадыженск Первомайская    Хадыженск
# 6166      3336.0           Нефтекамск Березовское шоссе  Нефтекамск
# 6167      4586.0                    Кушва на Строителей        Кушва
# 6168      3779.0        Боровичи ТЦ Фестиваль (ЗАКРЫТО)     Боровичи
#
# [6169 rows x 3 columns]

# %%
df_checkerboard_salary = df_actual_staff \
    .merge(df_branch_city, left_on='ТекущийФилиал', right_on='BranchCode') \
    .merge(df_PosLvlSalary, left_on=['Город', 'Должность', 'УровеньОплаты'], right_on=['Город', 'Должность', 'Уровень'], how='left')

# df_checkerboard_salary['ДатаОбновления'] = df_checkerboard_salary['ДатаОбновления'].dt.strftime('%Y-%m-%d')
df_checkerboard_salary = df_checkerboard_salary[['Город', 'Филиал', 'Должность', 
                        'УровеньОплаты', 'Зарплата','КоличествоСотрудников']]
df_checkerboard_salary 
# 18563 47433 48650 18809
# Out:
#                  Город                                   Филиал  \
# 0          Владивосток                  Видеостудия Владивосток
# 1          Владивосток                  Видеостудия Владивосток
# 2          Владивосток                  Видеостудия Владивосток
# 3          Владивосток                  Видеостудия Владивосток
# 4          Владивосток                  Видеостудия Владивосток
# ...                ...                                      ...
# 18802      Владивосток                              Фед. HR ФКО
# 18803      Владивосток                              Фед. HR ФКО
# 18804  Санкт-Петербург                            HR-Служба Спб
# 18805      Владивосток  Фед. отдел рекламных проектов (ЗАКРЫТО)
# 18806  Санкт-Петербург                      Фед. отдел IT - СПБ
#
#                                                Должность  УровеньОплаты  \
# 0                               Администратор киностудии            2.0
# 1                              Ведущий менеджер контента            1.0
# 2                                       Главный редактор            2.0
# 3                                Руководитель киностудии            2.0
# 4                   Руководитель контентного направления            3.0
# ...                                                  ...            ...
# 18802  Федеральный менеджер по подбору и работе с пер...            3.0
# 18803      Федеральный специалист коммерческих процессов            3.0
# 18804  Федеральный менеджер по подбору и работе с пер...            3.0
# 18805                  Федеральный специалист по рекламе            2.0
# 18806              Федеральный специалист тех. поддержки            2.0
#
#        Зарплата  КоличествоСотрудников
# 0       80000.0                      1
# 1       70000.0                      1
# 2       80000.0                      1
# 3       90000.0                      1
# 4      130000.0                      1
# ...         ...                    ...
# 18802   80000.0                      1
# 18803  100000.0                      1
# 18804   80000.0                      1
# 18805   50000.0                      1
# 18806   50000.0                      1
#
# [18807 rows x 6 columns]

# %%
df_checkerboard_salary[df_checkerboard_salary['Зарплата'].isna()]['Город'].unique()
# Out:
# array(['Екатеринбург', 'Комсомольск-на-Амуре', 'Москва', 'Краснодар',
#        'Пенза', 'Самара', 'Уфа', 'Челябинск', 'Красноярск', 'Владивосток',
#        'Нижний Новгород', 'Благовещенск', 'Санкт-Петербург', 'Щёкино',
#        'Вязьма', 'Ижевск', 'Казань', 'Иркутск', 'Новосибирск',
#        'Евпатория'], dtype=object)

# %%
# filt = df_checkerboard_salary['Город'] == 'Владивосток' 
# df_checkerboard_salary.loc[filt][df_checkerboard_salary['Зарплата'].isna()]
qqq =df_checkerboard_salary[df_checkerboard_salary['Зарплата'].isna()]
qqq
# Out:
#                       Город                         Филиал  \
# 472            Екатеринбург                   HR (д. Урал)
# 880    Комсомольск-на-Амуре      Комсомольск Вокзальная ТП
# 1047                 Москва     Москва Корпоративный отдел
# 1257              Краснодар           Краснодар Корпоратив
# 1275                  Пенза      Пенза Корпоративный отдел
# 1768                 Самара                   Самара Склад
# 1935                    Уфа                      Уфа Склад
# 1936                    Уфа                      Уфа Склад
# 2323              Челябинск                         ЧБ РСЦ
# 2426             Красноярск               Красноярск Склад
# 2543            Владивосток                 DNS-Group РКЦ
# 3045        Нижний Новгород                 Н.Новгород ДСЦ
# 3083             Красноярск              Кра СЦ Красноярье
# 3206            Владивосток           Фед. деп. ТВ и Аудио
# 3837             Красноярск              Кра ТЦ Мега Гипер
# 3841             Красноярск              Кра ТЦ Мега Гипер
# 5673           Благовещенск  Благовещенск ТЦ Острова Гипер
# 6836        Санкт-Петербург        СПб Склад в Горелово ТП
# 9504                 Щёкино             Щекино на Лукашина
# 11097                Вязьма               Вязьма ТЦ Orange
# 13673       Нижний Новгород            Н.Новгород Доставка
# 13898                Ижевск                      Ижевск СЦ
# 15334                Казань                     Казань ОСА
# 15602               Иркутск  Отдел кадров Восточная Сибирь
# 15603               Иркутск  Отдел кадров Восточная Сибирь
# 16271           Новосибирск             Отдел логистики ЗС
# 16456               Иркутск               Иркутск СЦ Базар
# 17049             Евпатория       Адм. тер. Сервис Юг Крым
#
#                                                Должность  УровеньОплаты  \
# 472    Руководитель отдела по обучению и развитию пер...            2.0
# 880                              Ведущий специалист в КО            NaN
# 1047                             Ведущий специалист в КО            NaN
# 1257                             Ведущий специалист в КО            NaN
# 1275                             Ведущий специалист в КО            NaN
# 1768                                    Кладовщик на РРЦ            NaN
# 1935                                    Кладовщик на РРЦ            NaN
# 1936                                    Кладовщик на РРЦ            NaN
# 2323                                      Логист сервиса            NaN
# 2426                                    Кладовщик на РРЦ            NaN
# 2543                                            Директор            NaN
# 3045          Заместитель управляющего сервисным центром            NaN
# 3083                        Специалист сервисного центра            NaN
# 3206        Федеральный коммерческий специалист 1 уровня            NaN
# 3837                                  Кладовщик магазина            NaN
# 3841                              Продавец - консультант            NaN
# 5673                              Продавец - консультант            NaN
# 6836                                              Кассир            NaN
# 9504                                              Кассир            NaN
# 11097                               Кредитный специалист            NaN
# 13673                         Сотрудник службы доставки             NaN
# 13898                       Специалист сервисного центра            NaN
# 15334                    Менеджер гарантийной отчетности            NaN
# 15602                     Помощник специалиста по кадрам            2.0
# 15603                         Руководитель отдела кадров            3.0
# 16271                  Старший сотрудник службы доставки            2.0
# 16456                       Специалист сервисного центра            NaN
# 17049               Территориальный управляющий сервисом            2.0
#
#        Зарплата  КоличествоСотрудников
# 472         NaN                      1
# 880         NaN                      1
# 1047        NaN                      1
# 1257        NaN                      1
# 1275        NaN                      1
# 1768        NaN                      1
# 1935        NaN                      1
# 1936        NaN                      2
# 2323        NaN                      1
# 2426        NaN                      1
# 2543        NaN                      1
# 3045        NaN                      1
# 3083        NaN                      1
# 3206        NaN                      1
# 3837        NaN                      1
# 3841        NaN                      1
# 5673        NaN                      1
# 6836        NaN                      1
# 9504        NaN                      1
# 11097       NaN                      1
# 13673       NaN                      1
# 13898       NaN                      1
# 15334       NaN                      2
# 15602       NaN                      1
# 15603       NaN                      1
# 16271       NaN                      6
# 16456       NaN                      1
# 17049       NaN                      1
