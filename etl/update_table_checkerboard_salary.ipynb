# %%
import pandas as pd
import pymssql
from clickhouse_driver import Client
from sqlalchemy import create_engine
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
pd. set_option('display.max_rows', 200)

# %%
def execute_clickhouse(query="select 'Test' as Test",
                       database='mart_hr',
                       external_tables=None,
                       **kwargs) -> pd.DataFrame:
    """
    Функция для выполнения запросов к Clickhouse

    **Аргументы:**

    - `query: str` - запрос
    - `database: str` - база данных (по-умолчанию `'dns_log'`)
    - `external_tables: pandas.DataFrame` - датафрэйм из которого бдует генерироваться внешняя таблица

    **Возвращает:**
    >    `pandas.DataFrame` с результатом запроса
    """
    client = Client(
        host='adm-dwh-ch1.dns-shop.ru',
        port='9000',
        database=database,
        user='peredereev.ro',
        password='RrfrOPjcoi3Mk6t'
    )
    if external_tables:
        pass
        #external_tables = [df_to_table(table[0], table[1]) for table in external_tables]
    rv = client.execute(query, external_tables=external_tables, with_column_types=True)
    df = pd.DataFrame(rv[0])
    df.columns = [i[0] for i in rv[1]]
    return df

def execute_pg_hr(query):
    """Функция обращения к хранилищу mart_hr DNS на чтение
    Параметры:
    query - строка, SQL запрос
    Возвращает - pandas DataFrame с содержанием результата выполнения запроса, названия столбцов из запроса"""

    host = 'adm-dwh-pg1.dns-shop.ru'
    schema = 'mart_hr'
    login = 'db_hr'
    password = 'eD3IdP'

    conection_url = f'postgresql+psycopg2://{login}:{password}@{host}/{schema}'

    engine = create_engine(conection_url)
    df = pd.read_sql(query, engine)
    engine.dispose()
    return df

def get_postgres_connection_string(connection_id) -> str:
    """
    Возвращает строку подключения к postgres для указанного подключения
    :return:
    """
    class connection:
        login = 'db_hr'
        password = 'eD3IdP'
        host = 'adm-dwh-pg1.dns-shop.ru'
        port = '5432'
        schema = 'mart_hr'

    return f'postgresql+psycopg2://{connection.login}:{connection.password}@{connection.host}:{connection.port}/{connection.schema}'

def execute_onec(query):
    """Функция обращения к Хранилищу DNS на чтение
    Параметры:
    query - строка, SQL запрос
    Возвращает - pandas DataFrame с содержанием результата выполнения запроса, названия столбцов из запроса"""
    ADuser = 'PARTNER\Peredereev.RO'
    ADpassword = 'Poki4poki4228'
    # ADuser = Config.ONEC_LOGIN
    # ADpassword = Config.ONEC_PASSWORD
    conn = pymssql.connect(server='10.10.33.220', user=ADuser, password=ADpassword, database='dns_m')
    df = pd.read_sql(query, conn)
    
    return df

# %%
def GetPosLvlSalary():
    query = f"""                                                                                                                                                                               
	 WITH first_query AS
            (
            SELECT  
            --		reg_table.Должность AS Должность
                    ШтатноеРасписание.Наименование AS Должность
                    ,reg_table.Уровень AS Уровень
                    ,dwh.[Справочник.Города].Наименование AS Город
                    ,dwh.[Справочник.Города].Код AS КодГорода
                    ,reg_table.Значение AS Зарплата
                    , MAX(Период) OVER (PARTITION BY reg_table.Город, reg_table.Должность, reg_table.Уровень) AS max_period
                    ,reg_table.Период as Период
                    ,ШтатноеРасписание.ЛидерскийУровень  
            FROM dwh.[РегистрСведений.УровеньЗаработнойПлаты] AS reg_table
            JOIN dwh.[Справочник.Города] ON reg_table.Город = dwh.[Справочник.Города].Ссылка 
            JOIN dwh.[Справочник.ШтатноеРасписание] ШтатноеРасписание ON reg_table.Должность  =  ШтатноеРасписание.Ссылка  
                AND ШтатноеРасписание.ПрефиксКДолжности NOT IN  ('ДОМ', 'ГРП')
            )

            SELECT Город,КодГорода, Должность, Уровень, Зарплата, Период, max_period, CONVERT(DATE, GETDATE()) AS ДатаОбновления, ЛидерскийУровень
            FROM  first_query
            WHERE Период = max_period
                AND Должность != '2.03. Фед.развитие сайта'
                AND Должность not like '%(на аутсорсе)%' 
            ORDER BY Должность, Уровень
			 """
    df = execute_onec(query)
    return df

# %%
def getActualStaff():
    query = f"""
select
     as2."Должность"
    , as2."УровеньОплаты"
    , as2."ТекущийФилиал"
    ,count(*) as КоличествоСотрудников
    , as2."РРС"
    , as2."Город"
    , as2."Филиал"
  from actual_staff as2
  where as2."Должность" not like '%%(на аутсорсе)%%'
  group by as2."Должность", as2."УровеньОплаты", as2."ТекущийФилиал", as2."ДатаОбновления", as2."Город", as2."Филиал", as2."РРС" 
  order by as2."Должность", as2."ТекущийФилиал", as2."УровеньОплаты" 
  """
    df = execute_pg_hr(query)
    return df

# %%
def getLossBranches():

	"""НазваниеФирмы	НазваниеГорода	Территория	Должность	Уровень"""

	query = f"""
	
WITH МаксДатаЦТЕ AS (
	select 
	--	DATEFROMPARTS(YEAR(Дата), MONTH(Дата), 1) AS Дата
			Дата
		, сф.Наименование AS НазваниеФирмы 
		, сг.Код AS КодГорода 
		, сг.Наименование as НазваниеГорода
		, сф.Код as Фирма
		, сшр.Наименование as Должность
		, душрс.КоличествоСтавок
		, max(Дата) OVER (PARTITION BY сф.Код, сшр.Наименование) AS МаксДата
		, ст.Наименование AS Территория
	from dwh.[Документ.УтверждениеШтатногоРасписания] душр
	join (
		select Фирма, YEAR(Дата) as Год, MONTH(Дата) as Месяц, MAX(DAY(Дата)) as День
		from dwh.[Документ.УтверждениеШтатногоРасписания] душрa 
		group by Фирма, YEAR(Дата), MONTH(Дата)
		) tmp
		on tmp.Год = YEAR(душр.Дата)
		and tmp.Месяц = MONTH(душр.Дата)
		and tmp.День = DAY(душр.Дата)
		and tmp.Фирма = душр.Фирма 
	join dwh.[Документ.УтверждениеШтатногоРасписания.Состав] душрс
		on душрс.Ссылка = душр.Ссылка
	join dwh.[Справочник.Фирмы] сф 
		on сф.Ссылка = душр.Фирма 
	join dwh.[Справочник.ШтатноеРасписание] сшр 
		on сшр.Ссылка = душрс.Должность 
	JOIN dwh.[Справочник.Города] сг 
		ON сф.Город = сг.Ссылка 
	JOIN dwh.[Справочник.Фирмы.ИерархияТерриторий] сфит 
		ON сф.Ссылка = сфит.Ссылка 
			AND сфит.Уровень = 3 
	JOIN dwh.[Справочник.Территории] ст 
		ON сфит.Территория = ст.Ссылка 
	where Дата >= '2021-01-01'
		and Проведен = 0x01
	--	    AND сф.Код = 1293
	--	order by душр.Дата

	), result_table AS
	(
	SELECT НазваниеФирмы, НазваниеГорода, Территория, Должность
	FROM МаксДатаЦТЕ
	WHERE МаксДата = Дата
	group by НазваниеФирмы, НазваниеГорода, Должность, Территория
	)

	select rt1.*
		, 1 as Уровень
	from result_table rt1
	union all 
	select rt2.*
		, 2 as Уровень
	from result_table rt2
	union all
	select rt3.*
		, 3 as Уровень
	from result_table rt3			

	"""
	df = execute_onec(query)
	return df

# %%
df_PosLvlSalary = GetPosLvlSalary()
df_PosLvlSalary
# Out:
#              Город  КодГорода                               Должность  \
# 0      Владивосток        1.0                            Web-дизайнер
# 1      Владивосток        1.0                            Web-дизайнер
# 2      Владивосток        1.0                            Web-дизайнер
# 3      Владивосток        1.0                Администратор киностудии
# 4      Владивосток        1.0                Администратор киностудии
# ...            ...        ...                                     ...
# 63725  Владивосток        1.0  Юрист в отдел по работе с поставщиками
# 63726  Владивосток        1.0  Юрист в отдел по работе с поставщиками
# 63727  Владивосток        1.0                    Юрист службы сервиса
# 63728  Владивосток        1.0                    Юрист службы сервиса
# 63729  Владивосток        1.0                    Юрист службы сервиса
#
#        Уровень  Зарплата     Период max_period ДатаОбновления  \
# 0          1.0   50000.0 2020-02-01 2020-02-01     2022-07-21
# 1          2.0   55000.0 2020-02-01 2020-02-01     2022-07-21
# 2          3.0   60000.0 2020-02-01 2020-02-01     2022-07-21
# 3          1.0   70000.0 2022-01-01 2022-01-01     2022-07-21
# 4          2.0   80000.0 2022-01-01 2022-01-01     2022-07-21
# ...        ...       ...        ...        ...            ...
# 63725      2.0   60000.0 2019-02-01 2019-02-01     2022-07-21
# 63726      3.0   65000.0 2019-02-01 2019-02-01     2022-07-21
# 63727      1.0   70000.0 2022-07-01 2022-07-01     2022-07-21
# 63728      2.0   80000.0 2022-07-01 2022-07-01     2022-07-21
# 63729      3.0   90000.0 2022-07-01 2022-07-01     2022-07-21
#
#        ЛидерскийУровень
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 63725               1.0
# 63726               1.0
# 63727               1.0
# 63728               1.0
# 63729               1.0
#
# [63730 rows x 9 columns]

# %%
df_actual_staff = getActualStaff()
df_actual_staff
# Out:
#                       Должность  УровеньОплаты  ТекущийФилиал  \
# 0      Администратор киностудии            2.0         2421.0
# 1           Администратор офиса            2.0          284.0
# 2           Администратор офиса            3.0          292.0
# 3           Администратор офиса            1.0          897.0
# 4           Администратор офиса            2.0          897.0
# ...                         ...            ...            ...
# 18561                     Юрист            3.0         5822.0
# 18562                     Юрист            1.0         5823.0
# 18563                     Юрист            2.0         5823.0
# 18564                     Юрист            3.0         5823.0
# 18565      Юрист службы сервиса            2.0         6155.0
#
#        КоличествоСотрудников                            РРС        Город  \
# 0                          1          Производство контента  Владивосток
# 1                          1  див. Центральный (Управление)       Москва
# 2                          1   див. Черноземье (Управление)      Воронеж
# 3                          1           див. ЗС (Управление)  Новосибирск
# 4                          1           див. ЗС (Управление)  Новосибирск
# ...                      ...                            ...          ...
# 18561                      1        Фед. юридическая служба  Владивосток
# 18562                      2        Фед. юридическая служба  Владивосток
# 18563                      1        Фед. юридическая служба  Владивосток
# 18564                      1        Фед. юридическая служба  Владивосток
# 18565                      3                         Сервис  Владивосток
#
#                                          Филиал
# 0                       Видеостудия Владивосток
# 1                    Адм. дивизиона Центральный
# 2                     Адм. дивизиона Черноземье
# 3                Адм. дивизиона Западная Сибирь
# 4                Адм. дивизиона Западная Сибирь
# ...                                         ...
# 18561  Направление ЮО по работе с поставщиками
# 18562       Направление ЮО по работе с розницей
# 18563       Направление ЮО по работе с розницей
# 18564       Направление ЮО по работе с розницей
# 18565                     Юридический отдел ФОС
#
# [18566 rows x 7 columns]

# %%
df_loss_branches = getLossBranches()
df_loss_branches
# Out:
#                                  НазваниеФирмы   НазваниеГорода  \
# 0       Отдел управления комм. процессами адм.  РКЦ Владивосток
# 1       Отдел управления комм. процессами адм.  РКЦ Владивосток
# 2       Отдел управления комм. процессами адм.  РКЦ Владивосток
# 3                       РКЦ Филиал Центральный           Москва
# 4                       РКЦ Филиал Центральный           Москва
# ...                                        ...              ...
# 59566                          Яшкино в Центре           Яшкино
# 59567                          Яшкино в Центре           Яшкино
# 59568                          Яшкино в Центре           Яшкино
# 59569                          Яшкино в Центре           Яшкино
# 59570                          Яшкино в Центре           Яшкино
#
#                           Территория  \
# 0                     Техноструктура
# 1                     Техноструктура
# 2                     Техноструктура
# 3      див. Центральный (Управление)
# 4      див. Центральный (Управление)
# ...                              ...
# 59566                РРС ЗС Кемерово
# 59567                РРС ЗС Кемерово
# 59568                РРС ЗС Кемерово
# 59569                РРС ЗС Кемерово
# 59570                РРС ЗС Кемерово
#
#                                            Должность  Уровень
# 0                    Менеджер коммерческих процессов        1
# 1                  Руководитель коммерческого отдела        1
# 2      Федеральный специалист коммерческих процессов        1
# 3                                          Бухгалтер        1
# 4              Бухгалтер по расчету заработной платы        1
# ...                                              ...      ...
# 59566                     Зам. управляющего магазина        3
# 59567               Универсальный сотрудник магазина        3
# 59568   Универсальный сотрудник магазина 1 категории        3
# 59569   Универсальный сотрудник магазина 2 категории        3
# 59570             Управляющий маг. средней категории        3
#
# [59571 rows x 5 columns]

# %%
df_main =  df_loss_branches\
    .merge(df_actual_staff, left_on=['НазваниеФирмы', 'Должность', 'Уровень'], right_on=['Филиал', 'Должность', 'УровеньОплаты'], how='left')
df_main['Город'] = df_main['Город'].fillna(df_main['НазваниеГорода'])
df_main['Филиал'] = df_main['Филиал'].fillna(df_main['НазваниеФирмы'])
df_main['Территория'] = df_main['РРС'].fillna(df_main['Территория'])
df_main['КоличествоСотрудников'] = df_main['КоличествоСотрудников'].fillna(0)
df_main
# Out:
#                                  НазваниеФирмы   НазваниеГорода  \
# 0       Отдел управления комм. процессами адм.  РКЦ Владивосток
# 1       Отдел управления комм. процессами адм.  РКЦ Владивосток
# 2       Отдел управления комм. процессами адм.  РКЦ Владивосток
# 3                       РКЦ Филиал Центральный           Москва
# 4                       РКЦ Филиал Центральный           Москва
# ...                                        ...              ...
# 59725                          Яшкино в Центре           Яшкино
# 59726                          Яшкино в Центре           Яшкино
# 59727                          Яшкино в Центре           Яшкино
# 59728                          Яшкино в Центре           Яшкино
# 59729                          Яшкино в Центре           Яшкино
#
#                           Территория  \
# 0                     Техноструктура
# 1                     Техноструктура
# 2                     Техноструктура
# 3      див. Центральный (Управление)
# 4      див. Центральный (Управление)
# ...                              ...
# 59725                РРС ЗС Кемерово
# 59726                РРС ЗС Кемерово
# 59727                РРС ЗС Кемерово
# 59728                РРС ЗС Кемерово
# 59729                РРС ЗС Кемерово
#
#                                            Должность  Уровень  УровеньОплаты  \
# 0                    Менеджер коммерческих процессов        1            NaN
# 1                  Руководитель коммерческого отдела        1            1.0
# 2      Федеральный специалист коммерческих процессов        1            NaN
# 3                                          Бухгалтер        1            1.0
# 4              Бухгалтер по расчету заработной платы        1            NaN
# ...                                              ...      ...            ...
# 59725                     Зам. управляющего магазина        3            NaN
# 59726               Универсальный сотрудник магазина        3            NaN
# 59727   Универсальный сотрудник магазина 1 категории        3            3.0
# 59728   Универсальный сотрудник магазина 2 категории        3            NaN
# 59729             Управляющий маг. средней категории        3            NaN
#
#        ТекущийФилиал  КоличествоСотрудников                            РРС  \
# 0                NaN                    0.0                            NaN
# 1             3013.0                    1.0                 Техноструктура
# 2                NaN                    0.0                            NaN
# 3              902.0                    1.0  див. Центральный (Управление)
# 4                NaN                    0.0                            NaN
# ...              ...                    ...                            ...
# 59725            NaN                    0.0                            NaN
# 59726            NaN                    0.0                            NaN
# 59727         3784.0                    1.0                РРС ЗС Кемерово
# 59728            NaN                    0.0                            NaN
# 59729            NaN                    0.0                            NaN
#
#                  Город                                   Филиал
# 0      РКЦ Владивосток   Отдел управления комм. процессами адм.
# 1          Владивосток   Отдел управления комм. процессами адм.
# 2      РКЦ Владивосток   Отдел управления комм. процессами адм.
# 3               Москва                   РКЦ Филиал Центральный
# 4               Москва                   РКЦ Филиал Центральный
# ...                ...                                      ...
# 59725           Яшкино                          Яшкино в Центре
# 59726           Яшкино                          Яшкино в Центре
# 59727           Яшкино                          Яшкино в Центре
# 59728           Яшкино                          Яшкино в Центре
# 59729           Яшкино                          Яшкино в Центре
#
# [59730 rows x 11 columns]

# %%
df_checkerboard_salary = df_PosLvlSalary.merge(df_main, left_on=['Город','Должность', 'Уровень'], right_on=['Город', 'Должность', 'Уровень'], how='left')
df_checkerboard_salary = df_checkerboard_salary[['Территория','Город', 'Филиал', 'Должность', 
                        'Уровень', 'Зарплата','ЛидерскийУровень','КоличествоСотрудников']]

# %%
df_checkerboard_salary[df_checkerboard_salary['Филиал'] == 'Владивосток Галактика КБТ']
# Out:
#                  Территория        Город                     Филиал  \
# 5344   РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 8781   РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 10584  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 20186  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 22734  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 24176  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 25969  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 26100  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 26155  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 34404  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 36232  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 37072  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 40597  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 41633  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 42313  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 58856  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 59854  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 60617  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 63848  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 65572  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 69840  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 73299  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 76187  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 77425  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 83963  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 86748  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
# 87925  РРС ДВ "Владивосток"  Владивосток  Владивосток Галактика КБТ
#
#                                 Должность  Уровень  Зарплата  \
# 5344           Зам. управляющего магазина      1.0   60500.0
# 8781           Зам. управляющего магазина      2.0   66000.0
# 10584          Зам. управляющего магазина      3.0   71500.0
# 20186                  Кладовщик магазина      1.0   41000.0
# 22734                  Кладовщик магазина      2.0   45000.0
# 24176                  Кладовщик магазина      3.0   49500.0
# 25969             Консультант дискаунтера      1.0   33500.0
# 26100             Консультант дискаунтера      2.0   40500.0
# 26155             Консультант дискаунтера      3.0   43000.0
# 34404              Продавец - консультант      1.0   33500.0
# 36232              Продавец - консультант      2.0   40500.0
# 37072              Продавец - консультант      3.0   43000.0
# 40597         Сотрудник выдачи в магазине      1.0   37500.0
# 41633         Сотрудник выдачи в магазине      2.0   41000.0
# 42313         Сотрудник выдачи в магазине      3.0   45000.0
# 58856       Универсальный продавец-кассир      1.0   34000.0
# 59854       Универсальный продавец-кассир      2.0   37500.0
# 60617       Универсальный продавец-кассир      3.0   41000.0
# 63848    Универсальный сотрудник магазина      1.0   37500.0
# 65572    Универсальный сотрудник магазина      2.0   41000.0
# 69840    Универсальный сотрудник магазина      3.0   45000.0
# 73299                    Управляющий маг.      1.0   60500.0
# 76187                    Управляющий маг.      2.0   66000.0
# 77425                    Управляющий маг.      3.0   71500.0
# 83963  Управляющий маг. средней категории      1.0   77000.0
# 86748  Управляющий маг. средней категории      2.0   82500.0
# 87925  Управляющий маг. средней категории      3.0   88000.0
#
#        ЛидерскийУровень  КоличествоСотрудников
# 5344                2.0                    0.0
# 8781                2.0                    1.0
# 10584               2.0                    0.0
# 20186               1.0                    0.0
# 22734               1.0                    1.0
# 24176               1.0                    1.0
# 25969               1.0                    0.0
# 26100               1.0                    0.0
# 26155               1.0                    0.0
# 34404               1.0                    1.0
# 36232               1.0                    2.0
# 37072               1.0                    0.0
# 40597               1.0                    0.0
# 41633               1.0                    0.0
# 42313               1.0                    0.0
# 58856               1.0                    0.0
# 59854               1.0                    0.0
# 60617               1.0                    0.0
# 63848               1.0                    0.0
# 65572               1.0                    1.0
# 69840               1.0                    1.0
# 73299               2.0                    0.0
# 76187               2.0                    0.0
# 77425               2.0                    0.0
# 83963               2.0                    1.0
# 86748               2.0                    0.0
# 87925               2.0                    0.0

# %%
df_checkerboard_salary.isna().sum() # 3898
# Out:
# Территория               35682
# Город                        0
# Филиал                   35682
# Должность                    0
# Уровень                      0
# Зарплата                     0
# ЛидерскийУровень             0
# КоличествоСотрудников    35682
# dtype: int64

# %%
filt_test1 = df_test_1['УровеньОплаты'].isna()
df_test_1[filt_test1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\peredereev.ro\HR Dags GitLab\my_git_hr_airflow\report_system\etl\update_table_checkerboard_salary.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/peredereev.ro/HR%20Dags%20GitLab/my_git_hr_airflow/report_system/etl/update_table_checkerboard_salary.ipynb#ch0000014?line=0'>1</a> filt_test1 = df_test_1['УровеньОплаты'].isna()
#       <a href='vscode-notebook-cell:/c%3A/Users/peredereev.ro/HR%20Dags%20GitLab/my_git_hr_airflow/report_system/etl/update_table_checkerboard_salary.ipynb#ch0000014?line=1'>2</a> df_test_1[filt_test1]
#
# NameError: name 'df_test_1' is not defined

# %%
# filt = (df_checkerboard_salary['НазваниеФирмы'] == 'Владивосток Галактика КБТ') & (df_checkerboard_salary['Филиал'] == 'Владивосток Галактика КБТ') 
filt1 = (df_test_1['НазваниеФирмы'] == 'Владивосток Галактика КБТ')
df_test_1[filt1].head(135).sort_values(by=['Должность', 'Уровень'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\peredereev.ro\HR Dags GitLab\my_git_hr_airflow\report_system\etl\update_table_checkerboard_salary.ipynb Cell 15' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/peredereev.ro/HR%20Dags%20GitLab/my_git_hr_airflow/report_system/etl/update_table_checkerboard_salary.ipynb#ch0000015?line=0'>1</a> # filt = (df_checkerboard_salary['НазваниеФирмы'] == 'Владивосток Галактика КБТ') & (df_checkerboard_salary['Филиал'] == 'Владивосток Галактика КБТ')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/peredereev.ro/HR%20Dags%20GitLab/my_git_hr_airflow/report_system/etl/update_table_checkerboard_salary.ipynb#ch0000015?line=1'>2</a> filt1 = (df_test_1['НазваниеФирмы'] == 'Владивосток Галактика КБТ')
#       <a href='vscode-notebook-cell:/c%3A/Users/peredereev.ro/HR%20Dags%20GitLab/my_git_hr_airflow/report_system/etl/update_table_checkerboard_salary.ipynb#ch0000015?line=2'>3</a> df_test_1[filt1].head(135).sort_values(by=['Должность', 'Уровень'])
#
# NameError: name 'df_test_1' is not defined

# %%
df_checkerboard_salary['Филиал'].isna().sum()
# Out:
# 35682

# %%
# df_checkerboard_salary['НазваниеФирмы'].isna().sum()

# %%
df_checkerboard_salary['Филиал'].isna().sum()
# Out:
# 35682

# %%
df_checkerboard_salary
# Out:
#                   Территория        Город                   Филиал  \
# 0                        NaN  Владивосток                      NaN
# 1                        NaN  Владивосток                      NaN
# 2                        NaN  Владивосток                      NaN
# 3                        NaN  Владивосток                      NaN
# 4      Производство контента  Владивосток  Видеостудия Владивосток
# ...                      ...          ...                      ...
# 92614                    NaN  Владивосток                      NaN
# 92615                    NaN  Владивосток                      NaN
# 92616                    NaN  Владивосток                      NaN
# 92617                 Сервис  Владивосток    Юридический отдел ФОС
# 92618                    NaN  Владивосток                      NaN
#
#                                     Должность  Уровень  Зарплата  \
# 0                                Web-дизайнер      1.0   50000.0
# 1                                Web-дизайнер      2.0   55000.0
# 2                                Web-дизайнер      3.0   60000.0
# 3                    Администратор киностудии      1.0   70000.0
# 4                    Администратор киностудии      2.0   80000.0
# ...                                       ...      ...       ...
# 92614  Юрист в отдел по работе с поставщиками      2.0   60000.0
# 92615  Юрист в отдел по работе с поставщиками      3.0   65000.0
# 92616                    Юрист службы сервиса      1.0   70000.0
# 92617                    Юрист службы сервиса      2.0   80000.0
# 92618                    Юрист службы сервиса      3.0   90000.0
#
#        ЛидерскийУровень  КоличествоСотрудников
# 0                   1.0                    NaN
# 1                   1.0                    NaN
# 2                   1.0                    NaN
# 3                   1.0                    NaN
# 4                   1.0                    1.0
# ...                 ...                    ...
# 92614               1.0                    NaN
# 92615               1.0                    NaN
# 92616               1.0                    NaN
# 92617               1.0                    3.0
# 92618               1.0                    NaN
#
# [92619 rows x 8 columns]

# %%
df_checkerboard_salary['Филиал'] = df_checkerboard_salary['Филиал'].fillna(df_checkerboard_salary['НазваниеФирмы'])

# %%
df = df_checkerboard_salary[['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников']]

# %%
qqq = df_checkerboard_salary.groupby(['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников'], as_index=False)['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников']
# Out:
# C:\Users\peredereev.ro\AppData\Local\Temp\ipykernel_14816\461515408.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   qqq = df_checkerboard_salary.groupby(['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников'], as_index=False)['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников']

# %%
qqq.size()
# Out:
#         Город                                     Должность  Уровень  \
# 0       Абаза              Универсальный сотрудник магазина      1.0
# 1       Абаза              Универсальный сотрудник магазина      2.0
# 2       Абаза              Универсальный сотрудник магазина      3.0
# 3       Абаза                              Управляющий маг.      1.0
# 4       Абаза                              Управляющий маг.      2.0
# ...       ...                                           ...      ...
# 41602  Яшкино  Универсальный сотрудник магазина 2 категории      2.0
# 41603  Яшкино  Универсальный сотрудник магазина 2 категории      3.0
# 41604  Яшкино            Управляющий маг. средней категории      1.0
# 41605  Яшкино            Управляющий маг. средней категории      2.0
# 41606  Яшкино            Управляющий маг. средней категории      3.0
#
#        Зарплата            Филиал  ЛидерскийУровень  КоличествоСотрудников  \
# 0       31000.0  Абаза ТК Околица               1.0                    1.0
# 1       34000.0  Абаза ТК Околица               1.0                    3.0
# 2       37000.0  Абаза ТК Околица               1.0                    0.0
# 3       55000.0  Абаза ТК Околица               2.0                    0.0
# 4       60000.0  Абаза ТК Околица               2.0                    1.0
# ...         ...               ...               ...                    ...
# 41602   25400.0   Яшкино в Центре               1.0                    1.0
# 41603   28000.0   Яшкино в Центре               1.0                    0.0
# 41604   65000.0   Яшкино в Центре               2.0                    0.0
# 41605   80000.0   Яшкино в Центре               2.0                    1.0
# 41606   90000.0   Яшкино в Центре               2.0                    0.0
#
#        size
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 41602     1
# 41603     1
# 41604     1
# 41605     1
# 41606     1
#
# [41607 rows x 8 columns]

# %%
df_checkerboard_salary[df_checkerboard_salary['Зарплата'].isna()]['Город'].unique()
# Out:
# array([], dtype=object)

# %%
# filt = df_checkerboard_salary['Город'] == 'Владивосток' 
# df_checkerboard_salary.loc[filt][df_checkerboard_salary['Зарплата'].isna()]
# qqq = qqq[qqq['Филиал'].isna()]
# qqq
