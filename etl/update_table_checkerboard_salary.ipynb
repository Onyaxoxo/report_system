# %%
import pandas as pd
import pymssql
from clickhouse_driver import Client
from sqlalchemy import create_engine
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
pd. set_option('display.max_rows', 200)

# %%
def execute_clickhouse(query="select 'Test' as Test",
                       database='mart_hr',
                       external_tables=None,
                       **kwargs) -> pd.DataFrame:
    """
    Функция для выполнения запросов к Clickhouse

    **Аргументы:**

    - `query: str` - запрос
    - `database: str` - база данных (по-умолчанию `'dns_log'`)
    - `external_tables: pandas.DataFrame` - датафрэйм из которого бдует генерироваться внешняя таблица

    **Возвращает:**
    >    `pandas.DataFrame` с результатом запроса
    """
    client = Client(
        host='',
        port='',
        database=database,
        user='',
        password=''
    )
    if external_tables:
        pass
        #external_tables = [df_to_table(table[0], table[1]) for table in external_tables]
    rv = client.execute(query, external_tables=external_tables, with_column_types=True)
    df = pd.DataFrame(rv[0])
    df.columns = [i[0] for i in rv[1]]
    return df

def execute_pg_hr(query):
    """Функция обращения к хранилищу mart_hr DNS на чтение
    Параметры:
    query - строка, SQL запрос
    Возвращает - pandas DataFrame с содержанием результата выполнения запроса, названия столбцов из запроса"""

    host = ''
    schema = ''
    login = ''
    password = ''

    conection_url = f'postgresql+psycopg2://{login}:{password}@{host}/{schema}'

    engine = create_engine(conection_url)
    df = pd.read_sql(query, engine)
    engine.dispose()
    return df

def get_postgres_connection_string(connection_id) -> str:
    """
    Возвращает строку подключения к postgres для указанного подключения
    :return:
    """
    class connection:
        login = ''
        password = ''
        host = ''
        port = ''
        schema = ''

    return f'postgresql+psycopg2://{connection.login}:{connection.password}@{connection.host}:{connection.port}/{connection.schema}'

def execute_onec(query):
    """Функция обращения к Хранилищу DNS на чтение
    Параметры:
    query - строка, SQL запрос
    Возвращает - pandas DataFrame с содержанием результата выполнения запроса, названия столбцов из запроса"""
    ADuser = ''
    ADpassword = ''
    # ADuser = Config.ONEC_LOGIN
    # ADpassword = Config.ONEC_PASSWORD
    conn = pymssql.connect(server='', user=ADuser, password=ADpassword, database='')
    df = pd.read_sql(query, conn)
    
    return df

# %%
def GetPosLvlSalary():
    query = f"""                                                                                                                                                                               
	 WITH first_query AS
            (
            SELECT  
            --		reg_table.Должность AS Должность
                    ШтатноеРасписание.Наименование AS Должность
                    ,reg_table.Уровень AS Уровень
                    ,dwh.[Справочник.Города].Наименование AS Город
                    ,dwh.[Справочник.Города].Код AS КодГорода
                    ,reg_table.Значение AS Зарплата
                    , MAX(Период) OVER (PARTITION BY reg_table.Город, reg_table.Должность, reg_table.Уровень) AS max_period
                    ,reg_table.Период as Период
                    ,ШтатноеРасписание.ЛидерскийУровень  
            FROM dwh.[РегистрСведений.УровеньЗаработнойПлаты] AS reg_table
            JOIN dwh.[Справочник.Города] ON reg_table.Город = dwh.[Справочник.Города].Ссылка 
            JOIN dwh.[Справочник.ШтатноеРасписание] ШтатноеРасписание ON reg_table.Должность  =  ШтатноеРасписание.Ссылка  
                AND ШтатноеРасписание.ПрефиксКДолжности NOT IN  ('ДОМ', 'ГРП')
            )

            SELECT Город,КодГорода, Должность, Уровень, Зарплата, Период, max_period, CONVERT(DATE, GETDATE()) AS ДатаОбновления, ЛидерскийУровень
            FROM  first_query
            WHERE Период = max_period
                AND Должность != '2.03. Фед.развитие сайта'
                AND Должность not like '%(на аутсорсе)%' 
            ORDER BY Должность, Уровень
			 """
    df = execute_onec(query)
    return df

# %%
def getActualStaff():
    query = f"""
  select
     as2."Должность"
    , as2."УровеньОплаты"
    , as2."ТекущийФилиал"
    ,count(*) as КоличествоСотрудников
    , as2."Город"
    , as2."Филиал"
  from actual_staff as2
  where as2."Должность" not like '%%(на аутсорсе)%%'
  group by as2."Должность", as2."УровеньОплаты", as2."ТекущийФилиал", as2."ДатаОбновления", as2."Город", as2."Филиал"
  order by as2."Должность", as2."ТекущийФилиал", as2."УровеньОплаты" 
  """
    df = execute_pg_hr(query)
    return df

# %%
def getBranchCity():
	query = f"""
	select 
	  bh.BranchCode 
	, bh.BranchName as "Филиал"
	, replace(bh.CityName, 'РКЦ ', '') as "Город"
from dns_retail.BranchHier bh 
	"""
	df = execute_clickhouse(query)
	return df

# %%
def getLossBranches():

	"""НазваниеФирмы	НазваниеГорода	Должность"""

	query = f"""
	WITH МаксДатаЦТЕ AS (
	select 
	--	DATEFROMPARTS(YEAR(Дата), MONTH(Дата), 1) AS Дата
			Дата
		, сф.Наименование AS НазваниеФирмы 
		, сг.Код AS КодГорода 
		, сг.Наименование as НазваниеГорода
		, сф.Код as Фирма
		, сшр.Наименование as Должность
		, душрс.КоличествоСтавок
		, max(Дата) OVER (PARTITION BY сф.Код, сшр.Наименование) AS МаксДата
	from dwh.[Документ.УтверждениеШтатногоРасписания] душр
	join (
		select Фирма, YEAR(Дата) as Год, MONTH(Дата) as Месяц, MAX(DAY(Дата)) as День
		from dwh.[Документ.УтверждениеШтатногоРасписания] душрa 
		group by Фирма, YEAR(Дата), MONTH(Дата)
		) tmp
		on tmp.Год = YEAR(душр.Дата)
		and tmp.Месяц = MONTH(душр.Дата)
		and tmp.День = DAY(душр.Дата)
		and tmp.Фирма = душр.Фирма 
	join dwh.[Документ.УтверждениеШтатногоРасписания.Состав] душрс
		on душрс.Ссылка = душр.Ссылка
	join dwh.[Справочник.Фирмы] сф 
		on сф.Ссылка = душр.Фирма 
	join dwh.[Справочник.ШтатноеРасписание] сшр 
		on сшр.Ссылка = душрс.Должность 
	JOIN dwh.[Справочник.Города] сг 
		ON сф.Город = сг.Ссылка 
	where Дата >= '2021-01-01'
		and Проведен = 0x01
	--	    AND сф.Код = 1293
	--	order by душр.Дата

	), result_table AS
	(
	SELECT НазваниеФирмы, НазваниеГорода, Должность
	FROM МаксДатаЦТЕ
	WHERE МаксДата = Дата
	group by НазваниеФирмы, НазваниеГорода, Должность
	)

	select rt1.*
		, 1 as Уровень
	from result_table rt1
	union all 
	select rt2.*
		, 2 as Уровень
	from result_table rt2
	union all
	select rt3.*
		, 3 as Уровень
	from result_table rt3				

	"""
	df = execute_onec(query)
	return df

# %%
df_PosLvlSalary = GetPosLvlSalary()
df_PosLvlSalary
# Out:
#              Город  КодГорода                               Должность  \
# 0      Владивосток        1.0                            Web-дизайнер
# 1      Владивосток        1.0                            Web-дизайнер
# 2      Владивосток        1.0                            Web-дизайнер
# 3      Владивосток        1.0                Администратор киностудии
# 4      Владивосток        1.0                Администратор киностудии
# ...            ...        ...                                     ...
# 63719  Владивосток        1.0  Юрист в отдел по работе с поставщиками
# 63720  Владивосток        1.0  Юрист в отдел по работе с поставщиками
# 63721  Владивосток        1.0                    Юрист службы сервиса
# 63722  Владивосток        1.0                    Юрист службы сервиса
# 63723  Владивосток        1.0                    Юрист службы сервиса
#
#        Уровень  Зарплата     Период max_period ДатаОбновления  \
# 0          1.0   50000.0 2020-02-01 2020-02-01     2022-07-19
# 1          2.0   55000.0 2020-02-01 2020-02-01     2022-07-19
# 2          3.0   60000.0 2020-02-01 2020-02-01     2022-07-19
# 3          1.0   70000.0 2022-01-01 2022-01-01     2022-07-19
# 4          2.0   80000.0 2022-01-01 2022-01-01     2022-07-19
# ...        ...       ...        ...        ...            ...
# 63719      2.0   60000.0 2019-02-01 2019-02-01     2022-07-19
# 63720      3.0   65000.0 2019-02-01 2019-02-01     2022-07-19
# 63721      1.0   70000.0 2022-07-01 2022-07-01     2022-07-19
# 63722      2.0   80000.0 2022-07-01 2022-07-01     2022-07-19
# 63723      3.0   90000.0 2022-07-01 2022-07-01     2022-07-19
#
#        ЛидерскийУровень
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 63719               1.0
# 63720               1.0
# 63721               1.0
# 63722               1.0
# 63723               1.0
#
# [63724 rows x 9 columns]

# %%
df_actual_staff = getActualStaff()
df_actual_staff
# Out:
#                       Должность  УровеньОплаты  ТекущийФилиал  \
# 0      Администратор киностудии            2.0         2421.0
# 1           Администратор офиса            2.0          284.0
# 2           Администратор офиса            3.0          292.0
# 3           Администратор офиса            1.0          897.0
# 4           Администратор офиса            2.0          897.0
# ...                         ...            ...            ...
# 18570                     Юрист            3.0         5822.0
# 18571                     Юрист            1.0         5823.0
# 18572                     Юрист            2.0         5823.0
# 18573                     Юрист            3.0         5823.0
# 18574      Юрист службы сервиса            2.0         6155.0
#
#        КоличествоСотрудников        Город  \
# 0                          1  Владивосток
# 1                          1       Москва
# 2                          1      Воронеж
# 3                          1  Новосибирск
# 4                          1  Новосибирск
# ...                      ...          ...
# 18570                      1  Владивосток
# 18571                      2  Владивосток
# 18572                      1  Владивосток
# 18573                      1  Владивосток
# 18574                      3  Владивосток
#
#                                          Филиал
# 0                       Видеостудия Владивосток
# 1                    Адм. дивизиона Центральный
# 2                     Адм. дивизиона Черноземье
# 3                Адм. дивизиона Западная Сибирь
# 4                Адм. дивизиона Западная Сибирь
# ...                                         ...
# 18570  Направление ЮО по работе с поставщиками
# 18571       Направление ЮО по работе с розницей
# 18572       Направление ЮО по работе с розницей
# 18573       Направление ЮО по работе с розницей
# 18574                     Юридический отдел ФОС
#
# [18575 rows x 6 columns]

# %%
df_loss_branches = getLossBranches()
df_loss_branches
# Out:
#                 НазваниеФирмы   НазваниеГорода  \
# 0        Федеральная дирекция  РКЦ Владивосток
# 1        Федеральная дирекция  РКЦ Владивосток
# 2        Федеральная дирекция  РКЦ Владивосток
# 3        Федеральная дирекция  РКЦ Владивосток
# 4        Федеральная дирекция  РКЦ Владивосток
# ...                       ...              ...
# 59554         Яшкино в Центре           Яшкино
# 59555         Яшкино в Центре           Яшкино
# 59556         Яшкино в Центре           Яшкино
# 59557         Яшкино в Центре           Яшкино
# 59558         Яшкино в Центре           Яшкино
#
#                                                Должность  Уровень
# 0                                               Директор        1
# 1                                   Директор по закупкам        1
# 2      Руководитель службы обучения и развития персонала        1
# 3                            Федеральный бизнес аналитик        1
# 4                                   Федеральный директор        1
# ...                                                  ...      ...
# 59554                         Зам. управляющего магазина        3
# 59555                   Универсальный сотрудник магазина        3
# 59556       Универсальный сотрудник магазина 1 категории        3
# 59557       Универсальный сотрудник магазина 2 категории        3
# 59558                 Управляющий маг. средней категории        3
#
# [59559 rows x 4 columns]

# %%
df_main =  df_loss_branches\
    .merge(df_actual_staff, left_on=['НазваниеФирмы', 'Должность', 'Уровень'], right_on=['Филиал', 'Должность', 'УровеньОплаты'], how='left')
df_main['Город'] = df_main['Город'].fillna(df_main['НазваниеГорода'])
df_main['Филиал'] = df_main['Филиал'].fillna(df_main['НазваниеФирмы'])
df_main['КоличествоСотрудников'] = df_main['КоличествоСотрудников'].fillna(0)
df_main
# Out:
#                 НазваниеФирмы   НазваниеГорода  \
# 0        Федеральная дирекция  РКЦ Владивосток
# 1        Федеральная дирекция  РКЦ Владивосток
# 2        Федеральная дирекция  РКЦ Владивосток
# 3        Федеральная дирекция  РКЦ Владивосток
# 4        Федеральная дирекция  РКЦ Владивосток
# ...                       ...              ...
# 59710         Яшкино в Центре           Яшкино
# 59711         Яшкино в Центре           Яшкино
# 59712         Яшкино в Центре           Яшкино
# 59713         Яшкино в Центре           Яшкино
# 59714         Яшкино в Центре           Яшкино
#
#                                                Должность  Уровень  \
# 0                                               Директор        1
# 1                                   Директор по закупкам        1
# 2      Руководитель службы обучения и развития персонала        1
# 3                            Федеральный бизнес аналитик        1
# 4                                   Федеральный директор        1
# ...                                                  ...      ...
# 59710                         Зам. управляющего магазина        3
# 59711                   Универсальный сотрудник магазина        3
# 59712       Универсальный сотрудник магазина 1 категории        3
# 59713       Универсальный сотрудник магазина 2 категории        3
# 59714                 Управляющий маг. средней категории        3
#
#        УровеньОплаты  ТекущийФилиал  КоличествоСотрудников            Город  \
# 0                NaN            NaN                    0.0  РКЦ Владивосток
# 1                NaN            NaN                    0.0  РКЦ Владивосток
# 2                NaN            NaN                    0.0  РКЦ Владивосток
# 3                NaN            NaN                    0.0  РКЦ Владивосток
# 4                NaN            NaN                    0.0  РКЦ Владивосток
# ...              ...            ...                    ...              ...
# 59710            NaN            NaN                    0.0           Яшкино
# 59711            NaN            NaN                    0.0           Яшкино
# 59712            3.0         3784.0                    1.0           Яшкино
# 59713            NaN            NaN                    0.0           Яшкино
# 59714            NaN            NaN                    0.0           Яшкино
#
#                        Филиал
# 0        Федеральная дирекция
# 1        Федеральная дирекция
# 2        Федеральная дирекция
# 3        Федеральная дирекция
# 4        Федеральная дирекция
# ...                       ...
# 59710         Яшкино в Центре
# 59711         Яшкино в Центре
# 59712         Яшкино в Центре
# 59713         Яшкино в Центре
# 59714         Яшкино в Центре
#
# [59715 rows x 9 columns]

# %%
df_checkerboard_salary = df_PosLvlSalary.merge(df_main, left_on=['Город','Должность', 'Уровень'], right_on=['Город', 'Должность', 'Уровень'], how='left')
df_checkerboard_salary = df_checkerboard_salary[['Город', 'Филиал', 'Должность', 
                        'Уровень', 'Зарплата','КоличествоСотрудников']]

# %%
df_checkerboard_salary[df_checkerboard_salary['Филиал'] == 'Владивосток Галактика КБТ']
# Out:
#              Город                     Филиал  \
# 3878   Владивосток  Владивосток Галактика КБТ
# 7309   Владивосток  Владивосток Галактика КБТ
# 9116   Владивосток  Владивосток Галактика КБТ
# 19008  Владивосток  Владивосток Галактика КБТ
# 21552  Владивосток  Владивосток Галактика КБТ
# 22998  Владивосток  Владивосток Галактика КБТ
# 25904  Владивосток  Владивосток Галактика КБТ
# 26035  Владивосток  Владивосток Галактика КБТ
# 26090  Владивосток  Владивосток Галактика КБТ
# 33565  Владивосток  Владивосток Галактика КБТ
# 35393  Владивосток  Владивосток Галактика КБТ
# 36233  Владивосток  Владивосток Галактика КБТ
# 40044  Владивосток  Владивосток Галактика КБТ
# 41078  Владивосток  Владивосток Галактика КБТ
# 41758  Владивосток  Владивосток Галактика КБТ
# 58336  Владивосток  Владивосток Галактика КБТ
# 59334  Владивосток  Владивосток Галактика КБТ
# 60097  Владивосток  Владивосток Галактика КБТ
# 62129  Владивосток  Владивосток Галактика КБТ
# 63854  Владивосток  Владивосток Галактика КБТ
# 68117  Владивосток  Владивосток Галактика КБТ
# 72060  Владивосток  Владивосток Галактика КБТ
# 74944  Владивосток  Владивосток Галактика КБТ
# 76183  Владивосток  Владивосток Галактика КБТ
# 82795  Владивосток  Владивосток Галактика КБТ
# 85577  Владивосток  Владивосток Галактика КБТ
# 86755  Владивосток  Владивосток Галактика КБТ
#
#                                 Должность  Уровень  Зарплата  \
# 3878           Зам. управляющего магазина      1.0   60500.0
# 7309           Зам. управляющего магазина      2.0   66000.0
# 9116           Зам. управляющего магазина      3.0   71500.0
# 19008                  Кладовщик магазина      1.0   41000.0
# 21552                  Кладовщик магазина      2.0   45000.0
# 22998                  Кладовщик магазина      3.0   49500.0
# 25904             Консультант дискаунтера      1.0   33500.0
# 26035             Консультант дискаунтера      2.0   40500.0
# 26090             Консультант дискаунтера      3.0   43000.0
# 33565              Продавец - консультант      1.0   33500.0
# 35393              Продавец - консультант      2.0   40500.0
# 36233              Продавец - консультант      3.0   43000.0
# 40044         Сотрудник выдачи в магазине      1.0   37500.0
# 41078         Сотрудник выдачи в магазине      2.0   41000.0
# 41758         Сотрудник выдачи в магазине      3.0   45000.0
# 58336       Универсальный продавец-кассир      1.0   34000.0
# 59334       Универсальный продавец-кассир      2.0   37500.0
# 60097       Универсальный продавец-кассир      3.0   41000.0
# 62129    Универсальный сотрудник магазина      1.0   37500.0
# 63854    Универсальный сотрудник магазина      2.0   41000.0
# 68117    Универсальный сотрудник магазина      3.0   45000.0
# 72060                    Управляющий маг.      1.0   60500.0
# 74944                    Управляющий маг.      2.0   66000.0
# 76183                    Управляющий маг.      3.0   71500.0
# 82795  Управляющий маг. средней категории      1.0   77000.0
# 85577  Управляющий маг. средней категории      2.0   82500.0
# 86755  Управляющий маг. средней категории      3.0   88000.0
#
#        КоличествоСотрудников
# 3878                     0.0
# 7309                     1.0
# 9116                     0.0
# 19008                    0.0
# 21552                    1.0
# 22998                    1.0
# 25904                    0.0
# 26035                    0.0
# 26090                    0.0
# 33565                    0.0
# 35393                    2.0
# 36233                    0.0
# 40044                    0.0
# 41078                    0.0
# 41758                    0.0
# 58336                    0.0
# 59334                    0.0
# 60097                    0.0
# 62129                    0.0
# 63854                    1.0
# 68117                    1.0
# 72060                    0.0
# 74944                    0.0
# 76183                    0.0
# 82795                    1.0
# 85577                    0.0
# 86755                    0.0

# %%
df_checkerboard_salary.isna().sum() # 3898
# Out:
# Город                        0
# Филиал                   35701
# Должность                    0
# Уровень                      0
# Зарплата                     0
# КоличествоСотрудников    35701
# dtype: int64

# %%
filt_test1 = df_test_1['УровеньОплаты'].isna()
df_test_1[filt_test1]
# Out:
#                     НазваниеФирмы   НазваниеГорода  \
# 0            Федеральная дирекция  РКЦ Владивосток
# 1            Федеральная дирекция  РКЦ Владивосток
# 2            Федеральная дирекция  РКЦ Владивосток
# 3            Федеральная дирекция  РКЦ Владивосток
# 4            Федеральная дирекция  РКЦ Владивосток
# ...                           ...              ...
# 59709  яЧишмы ТЦ Дружба (ЗАКРЫТО)            Чишмы
# 59710             Яшкино в Центре           Яшкино
# 59711             Яшкино в Центре           Яшкино
# 59713             Яшкино в Центре           Яшкино
# 59714             Яшкино в Центре           Яшкино
#
#                                                Должность  Уровень  \
# 0                                               Директор        1
# 1                                   Директор по закупкам        1
# 2      Руководитель службы обучения и развития персонала        1
# 3                            Федеральный бизнес аналитик        1
# 4                                   Федеральный директор        1
# ...                                                  ...      ...
# 59709                 Управляющий маг. средней категории        3
# 59710                         Зам. управляющего магазина        3
# 59711                   Универсальный сотрудник магазина        3
# 59713       Универсальный сотрудник магазина 2 категории        3
# 59714                 Управляющий маг. средней категории        3
#
#        УровеньОплаты  ТекущийФилиал  КоличествоСотрудников            Город  \
# 0                NaN            NaN                    0.0  РКЦ Владивосток
# 1                NaN            NaN                    0.0  РКЦ Владивосток
# 2                NaN            NaN                    0.0  РКЦ Владивосток
# 3                NaN            NaN                    0.0  РКЦ Владивосток
# 4                NaN            NaN                    0.0  РКЦ Владивосток
# ...              ...            ...                    ...              ...
# 59709            NaN            NaN                    0.0            Чишмы
# 59710            NaN            NaN                    0.0           Яшкино
# 59711            NaN            NaN                    0.0           Яшкино
# 59713            NaN            NaN                    0.0           Яшкино
# 59714            NaN            NaN                    0.0           Яшкино
#
#                            Филиал
# 0            Федеральная дирекция
# 1            Федеральная дирекция
# 2            Федеральная дирекция
# 3            Федеральная дирекция
# 4            Федеральная дирекция
# ...                           ...
# 59709  яЧишмы ТЦ Дружба (ЗАКРЫТО)
# 59710             Яшкино в Центре
# 59711             Яшкино в Центре
# 59713             Яшкино в Центре
# 59714             Яшкино в Центре
#
# [41387 rows x 9 columns]

# %%
# filt = (df_checkerboard_salary['НазваниеФирмы'] == 'Владивосток Галактика КБТ') & (df_checkerboard_salary['Филиал'] == 'Владивосток Галактика КБТ') 
filt1 = (df_test_1['НазваниеФирмы'] == 'Владивосток Галактика КБТ')
df_test_1[filt1].head(135).sort_values(by=['Должность', 'Уровень'])
# Out:
#                    НазваниеФирмы НазваниеГорода  \
# 3194   Владивосток Галактика КБТ    Владивосток
# 23131  Владивосток Галактика КБТ    Владивосток
# 43023  Владивосток Галактика КБТ    Владивосток
# 3195   Владивосток Галактика КБТ    Владивосток
# 23132  Владивосток Галактика КБТ    Владивосток
# 43024  Владивосток Галактика КБТ    Владивосток
# 3196   Владивосток Галактика КБТ    Владивосток
# 23133  Владивосток Галактика КБТ    Владивосток
# 43025  Владивосток Галактика КБТ    Владивосток
# 3197   Владивосток Галактика КБТ    Владивосток
# 23134  Владивосток Галактика КБТ    Владивосток
# 43026  Владивосток Галактика КБТ    Владивосток
# 3198   Владивосток Галактика КБТ    Владивосток
# 23135  Владивосток Галактика КБТ    Владивосток
# 43027  Владивосток Галактика КБТ    Владивосток
# 3199   Владивосток Галактика КБТ    Владивосток
# 23136  Владивосток Галактика КБТ    Владивосток
# 43028  Владивосток Галактика КБТ    Владивосток
# 3200   Владивосток Галактика КБТ    Владивосток
# 23137  Владивосток Галактика КБТ    Владивосток
# 43029  Владивосток Галактика КБТ    Владивосток
# 3201   Владивосток Галактика КБТ    Владивосток
# 23138  Владивосток Галактика КБТ    Владивосток
# 43030  Владивосток Галактика КБТ    Владивосток
# 3202   Владивосток Галактика КБТ    Владивосток
# 23139  Владивосток Галактика КБТ    Владивосток
# 43031  Владивосток Галактика КБТ    Владивосток
#
#                                 Должность  Уровень  УровеньОплаты  \
# 3194           Зам. управляющего магазина        1            NaN
# 23131          Зам. управляющего магазина        2            2.0
# 43023          Зам. управляющего магазина        3            NaN
# 3195                   Кладовщик магазина        1            NaN
# 23132                  Кладовщик магазина        2            2.0
# 43024                  Кладовщик магазина        3            3.0
# 3196              Консультант дискаунтера        1            NaN
# 23133             Консультант дискаунтера        2            NaN
# 43025             Консультант дискаунтера        3            NaN
# 3197               Продавец - консультант        1            NaN
# 23134              Продавец - консультант        2            2.0
# 43026              Продавец - консультант        3            NaN
# 3198          Сотрудник выдачи в магазине        1            NaN
# 23135         Сотрудник выдачи в магазине        2            NaN
# 43027         Сотрудник выдачи в магазине        3            NaN
# 3199        Универсальный продавец-кассир        1            NaN
# 23136       Универсальный продавец-кассир        2            NaN
# 43028       Универсальный продавец-кассир        3            NaN
# 3200     Универсальный сотрудник магазина        1            NaN
# 23137    Универсальный сотрудник магазина        2            2.0
# 43029    Универсальный сотрудник магазина        3            3.0
# 3201                     Управляющий маг.        1            NaN
# 23138                    Управляющий маг.        2            NaN
# 43030                    Управляющий маг.        3            NaN
# 3202   Управляющий маг. средней категории        1            1.0
# 23139  Управляющий маг. средней категории        2            NaN
# 43031  Управляющий маг. средней категории        3            NaN
#
#        ТекущийФилиал  КоличествоСотрудников        Город  \
# 3194             NaN                    0.0  Владивосток
# 23131         1703.0                    1.0  Владивосток
# 43023            NaN                    0.0  Владивосток
# 3195             NaN                    0.0  Владивосток
# 23132         1703.0                    1.0  Владивосток
# 43024         1703.0                    1.0  Владивосток
# 3196             NaN                    0.0  Владивосток
# 23133            NaN                    0.0  Владивосток
# 43025            NaN                    0.0  Владивосток
# 3197             NaN                    0.0  Владивосток
# 23134         1703.0                    2.0  Владивосток
# 43026            NaN                    0.0  Владивосток
# 3198             NaN                    0.0  Владивосток
# 23135            NaN                    0.0  Владивосток
# 43027            NaN                    0.0  Владивосток
# 3199             NaN                    0.0  Владивосток
# 23136            NaN                    0.0  Владивосток
# 43028            NaN                    0.0  Владивосток
# 3200             NaN                    0.0  Владивосток
# 23137         1703.0                    1.0  Владивосток
# 43029         1703.0                    1.0  Владивосток
# 3201             NaN                    0.0  Владивосток
# 23138            NaN                    0.0  Владивосток
# 43030            NaN                    0.0  Владивосток
# 3202          1703.0                    1.0  Владивосток
# 23139            NaN                    0.0  Владивосток
# 43031            NaN                    0.0  Владивосток
#
#                           Филиал
# 3194   Владивосток Галактика КБТ
# 23131  Владивосток Галактика КБТ
# 43023  Владивосток Галактика КБТ
# 3195   Владивосток Галактика КБТ
# 23132  Владивосток Галактика КБТ
# 43024  Владивосток Галактика КБТ
# 3196   Владивосток Галактика КБТ
# 23133  Владивосток Галактика КБТ
# 43025  Владивосток Галактика КБТ
# 3197   Владивосток Галактика КБТ
# 23134  Владивосток Галактика КБТ
# 43026  Владивосток Галактика КБТ
# 3198   Владивосток Галактика КБТ
# 23135  Владивосток Галактика КБТ
# 43027  Владивосток Галактика КБТ
# 3199   Владивосток Галактика КБТ
# 23136  Владивосток Галактика КБТ
# 43028  Владивосток Галактика КБТ
# 3200   Владивосток Галактика КБТ
# 23137  Владивосток Галактика КБТ
# 43029  Владивосток Галактика КБТ
# 3201   Владивосток Галактика КБТ
# 23138  Владивосток Галактика КБТ
# 43030  Владивосток Галактика КБТ
# 3202   Владивосток Галактика КБТ
# 23139  Владивосток Галактика КБТ
# 43031  Владивосток Галактика КБТ

# %%
df_checkerboard_salary['Филиал'].isna().sum()
# Out:
# 35701

# %%
# df_checkerboard_salary['НазваниеФирмы'].isna().sum()

# %%
df_checkerboard_salary['Филиал'].isna().sum()
# Out:
# 0

# %%
df_checkerboard_salary
# Out:
#                Город  КодГорода            Должность  Уровень  Зарплата  \
# 0        Новосибирск       19.0  Администратор офиса      1.0   30000.0
# 1        Новосибирск       19.0  Администратор офиса      2.0   35000.0
# 2        Новосибирск       19.0  Администратор офиса      3.0   40000.0
# 3            Воронеж       59.0  Администратор офиса      1.0   25000.0
# 4            Воронеж       59.0  Администратор офиса      1.0   25000.0
# ...              ...        ...                  ...      ...       ...
# 214928  Екатеринбург       24.0         Юрисконсульт      2.0   60000.0
# 214929  Екатеринбург       24.0         Юрисконсульт      3.0   70000.0
# 214930   Владивосток        1.0         Юрисконсульт      1.0   60000.0
# 214931   Владивосток        1.0         Юрисконсульт      2.0   70000.0
# 214932   Владивосток        1.0         Юрисконсульт      3.0   80000.0
#
#            Период max_period ДатаОбновления  ЛидерскийУровень  \
# 0      2019-02-01 2019-02-01     2022-07-19               1.0
# 1      2021-04-01 2021-04-01     2022-07-19               1.0
# 2      2021-04-01 2021-04-01     2022-07-19               1.0
# 3      2021-11-01 2021-11-01     2022-07-19               1.0
# 4      2021-11-01 2021-11-01     2022-07-19               1.0
# ...           ...        ...            ...               ...
# 214928 2021-12-01 2021-12-01     2022-07-19               1.0
# 214929 2021-12-01 2021-12-01     2022-07-19               1.0
# 214930 2021-12-01 2021-12-01     2022-07-19               1.0
# 214931 2021-12-01 2021-12-01     2022-07-19               1.0
# 214932 2021-12-01 2021-12-01     2022-07-19               1.0
#
#                          НазваниеФирмы НазваниеГорода  УровеньОплаты  \
# 0       Адм. дивизиона Западная Сибирь    Новосибирск            1.0
# 1       Адм. дивизиона Западная Сибирь    Новосибирск            2.0
# 2       Адм. дивизиона Западная Сибирь    Новосибирск            NaN
# 3            Адм. дивизиона Черноземье        Воронеж            1.0
# 4           Отдел персонала Черноземье        Воронеж            1.0
# ...                                ...            ...            ...
# 214928     Юридический Отдел (д. Урал)   Екатеринбург            2.0
# 214929     Юридический Отдел (д. Урал)   Екатеринбург            NaN
# 214930   Адм. дивизиона Дальний Восток    Владивосток            NaN
# 214931   Адм. дивизиона Дальний Восток    Владивосток            2.0
# 214932   Адм. дивизиона Дальний Восток    Владивосток            NaN
#
#         ТекущийФилиал  КоличествоСотрудников                          Филиал
# 0               897.0                    1.0  Адм. дивизиона Западная Сибирь
# 1               897.0                    1.0  Адм. дивизиона Западная Сибирь
# 2                 NaN                    0.0  Адм. дивизиона Западная Сибирь
# 3              5836.0                    1.0      Отдел персонала Черноземье
# 4              5836.0                    1.0      Отдел персонала Черноземье
# ...               ...                    ...                             ...
# 214928         5379.0                    1.0     Юридический Отдел (д. Урал)
# 214929            NaN                    0.0     Юридический Отдел (д. Урал)
# 214930            NaN                    0.0   Адм. дивизиона Дальний Восток
# 214931          899.0                    1.0   Адм. дивизиона Дальний Восток
# 214932            NaN                    0.0   Адм. дивизиона Дальний Восток
#
# [214933 rows x 15 columns]

# %%
df_checkerboard_salary['Филиал'] = df_checkerboard_salary['Филиал'].fillna(df_checkerboard_salary['НазваниеФирмы'])

# %%
df = df_checkerboard_salary[['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников']]

# %%
qqq = df_checkerboard_salary.groupby(['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников'], as_index=False)['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников']
# Out:
# C:\Users\peredereev.ro\AppData\Local\Temp\ipykernel_14816\461515408.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   qqq = df_checkerboard_salary.groupby(['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников'], as_index=False)['Город','Должность', 'Уровень', 'Зарплата', 'Филиал', 'ЛидерскийУровень', 'КоличествоСотрудников']

# %%
qqq.size()
# Out:
#         Город                                     Должность  Уровень  \
# 0       Абаза              Универсальный сотрудник магазина      1.0
# 1       Абаза              Универсальный сотрудник магазина      2.0
# 2       Абаза              Универсальный сотрудник магазина      3.0
# 3       Абаза                              Управляющий маг.      1.0
# 4       Абаза                              Управляющий маг.      2.0
# ...       ...                                           ...      ...
# 41602  Яшкино  Универсальный сотрудник магазина 2 категории      2.0
# 41603  Яшкино  Универсальный сотрудник магазина 2 категории      3.0
# 41604  Яшкино            Управляющий маг. средней категории      1.0
# 41605  Яшкино            Управляющий маг. средней категории      2.0
# 41606  Яшкино            Управляющий маг. средней категории      3.0
#
#        Зарплата            Филиал  ЛидерскийУровень  КоличествоСотрудников  \
# 0       31000.0  Абаза ТК Околица               1.0                    1.0
# 1       34000.0  Абаза ТК Околица               1.0                    3.0
# 2       37000.0  Абаза ТК Околица               1.0                    0.0
# 3       55000.0  Абаза ТК Околица               2.0                    0.0
# 4       60000.0  Абаза ТК Околица               2.0                    1.0
# ...         ...               ...               ...                    ...
# 41602   25400.0   Яшкино в Центре               1.0                    1.0
# 41603   28000.0   Яшкино в Центре               1.0                    0.0
# 41604   65000.0   Яшкино в Центре               2.0                    0.0
# 41605   80000.0   Яшкино в Центре               2.0                    1.0
# 41606   90000.0   Яшкино в Центре               2.0                    0.0
#
#        size
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 41602     1
# 41603     1
# 41604     1
# 41605     1
# 41606     1
#
# [41607 rows x 8 columns]

# %%
df_checkerboard_salary[df_checkerboard_salary['Зарплата'].isna()]['Город'].unique()
# Out:
# array([], dtype=object)

# %%
# filt = df_checkerboard_salary['Город'] == 'Владивосток' 
# df_checkerboard_salary.loc[filt][df_checkerboard_salary['Зарплата'].isna()]
# qqq = qqq[qqq['Филиал'].isna()]
# qqq
